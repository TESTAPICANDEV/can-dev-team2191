# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Import datasets , merging and transformations

# %%
df = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls April 2019.xlsx')

# %%
df.head()
# Out:
#     SRT # SRT Status Date Closed           Client Group Contact Method  \
# 0  507828     Closed  2019-04-03  Professional Services      Telephone
# 1  504475     Closed  2019-04-05  Professional Services      Telephone
# 2  509790     Closed  2019-04-25             Individual      Telephone
# 3  509929     Closed  2019-04-26             Individual      Telephone
# 4  508356     Closed  2019-04-08  Professional Services      Telephone
#
#   Postal/Zip Code City        Prov/State Country Language  \
# 0             NaN  NaN           Alberta  Canada  English
# 1             NaN  NaN  British Columbia  Canada  English
# 2             NaN  NaN  British Columbia  Canada  English
# 3             NaN  NaN            Québec  Canada   French
# 4             NaN  NaN          Manitoba  Canada  English
#
#                          Topic  \
# 0                   Bankruptcy
# 1                   Bankruptcy
# 2       Science and technology
# 3  Internet radio and wireless
# ...

# %%
df1 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls August 2019.xlsx')
df2 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls February 2019.xlsx')
df3 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls January 2019.xlsx')
df4 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls July 2019.xlsx')
df5 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls June 2019.xlsx')
df6 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls March 2019.xlsx')
df7 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Calls May 2019.xlsx')
df8 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Emails Jan. 1 to Aug. 31, 2019.xlsx')
df9 = pd.read_excel('C:/Users/vishal/Desktop/Candev/Contact Centre Data/Can Dev - Hackathon - Contact Centre Data - Web Chats Jan. 1 to Aug. 31, 2019.xlsx')

# %%
df2.head()
# Out:
#     SRT # SRT Status Date Closed Client Group Contact Method Postal/Zip Code  \
# 0  500361     Closed  2019-02-08   Individual      Telephone             NaN
# 1  500931     Closed  2019-02-14      Company      Telephone             NaN
# 2  500020     Closed  2019-02-08   Individual      Telephone             NaN
# 3  499085     Closed  2019-02-08   Individual      Telephone             NaN
# 4  502304     Closed  2019-02-26   Individual      Telephone             NaN
#
#   City Prov/State Country Language                        Topic  \
# 0  NaN    Ontario  Canada  English  Internet radio and wireless
# 1  NaN     Québec  Canada  English                 Corporations
# 2  NaN     Québec  Canada   French  Internet radio and wireless
# 3  NaN    Alberta  Canada  English  Internet radio and wireless
# 4  NaN     Québec  Canada   French  Internet radio and wireless
#
#                                         Organization  \
# 0  Innovation, Science and Economic Development C...
# ...

# %%
contactcentre = pd.concat([df, df1,df2,df3,df4,df5,df6,df7,df8,df9])

# %%
contactcentre.head(55)
# Out:
#     index   SRT # SRT Status Date Closed           Client Group  \
# 0    2165  495072     Closed  2019-01-02                Company
# 1    3339  495171     Closed  2019-01-02                Company
# 2    3338  495170     Closed  2019-01-02             Individual
# 3    3337  495052     Closed  2019-01-02             Individual
# 4    3336  495053     Closed  2019-01-02             Individual
# 5    3343  495179     Closed  2019-01-02             Individual
# 6    3353  495165     Closed  2019-01-02             Individual
# 7    3354  495158     Closed  2019-01-02                Unknown
# 8    3355  495160     Closed  2019-01-02                Unknown
# 9    3372  495191     Closed  2019-01-02                Company
# 10   3371  495183     Closed  2019-01-02             Individual
# 11   3340  495166     Closed  2019-01-02             Individual
# 12   3370  495185     Closed  2019-01-02             Individual
# 13   3368  495187     Closed  2019-01-02             Individual
# ...

# %%
contactcentre = contactcentre.sort_values(by='Date Closed') 
contactcentre = contactcentre.reset_index()

# %% [markdown]
# # Clean Twitter

# %%
import pandas as pd
import glob

path = r'C:/Users/vishal/Desktop/Candev/Social Media Data/CanadaBusiness' # use your path
all_files = glob.glob(path + "/*.xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
 CanadaBusiness
# Out:
#                 Tweet id                                    Tweet permalink  \
# 0    1122889548349020032  https://twitter.com/canadabusiness/status/1122...
# 1    1121802408844189952  https://twitter.com/canadabusiness/status/1121...
# 2    1121516756655389952  https://twitter.com/canadabusiness/status/1121...
# 3    1121501756037449984  https://twitter.com/canadabusiness/status/1121...
# 4    1121440007498140032  https://twitter.com/canadabusiness/status/1121...
# 5    1121094331396440064  https://twitter.com/canadabusiness/status/1121...
# 6    1120296526440480000  https://twitter.com/canadabusiness/status/1120...
# 7    1118957510722029952  https://twitter.com/canadabusiness/status/1118...
# 8    1118922452984310016  https://twitter.com/canadabusiness/status/1118...
# 9    1118903284599750016  https://twitter.com/canadabusiness/status/1118...
# 10   1118575182132710016  https://twitter.com/canadabusiness/status/1118...
# ...

# %%
CanadaBusiness =  CanadaBusiness.sort_values(by='time') 
CanadaBusiness =  CanadaBusiness.reset_index()

# %%
import pandas as pd
import glob

path = r'C:/Users/vishal/Desktop/Candev/Social Media Data/CDNScience' # use your path
all_files = glob.glob(path + "/*.xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

CDNScience = pd.concat(li, axis=0, ignore_index=True)

# %%
CDNScience
# Out:
#                 Tweet id                                    Tweet permalink  \
# 0    1101163894956060032  https://twitter.com/CDNScience/status/11011638...
# 1    1100801519644000000  https://twitter.com/CDNScience/status/11008015...
# 2    1100439120298540032  https://twitter.com/CDNScience/status/11004391...
# 3    1100094637505689984  https://twitter.com/CDNScience/status/11000946...
# 4    1100076732810509952  https://twitter.com/CDNScience/status/11000767...
# 5    1099006195573100032  https://twitter.com/CDNScience/status/10990061...
# 6    1098989577283469952  https://twitter.com/CDNScience/status/10989895...
# 7    1098643757245820032  https://twitter.com/CDNScience/status/10986437...
# 8    1098627195977840000  https://twitter.com/CDNScience/status/10986271...
# 9    1098264793344099968  https://twitter.com/CDNScience/status/10982647...
# 10   1097902404639609984  https://twitter.com/CDNScience/status/10979024...
# ...

# %%
CDNScience = CDNScience.sort_values(by='time') 
CDNScience =  CDNScience.reset_index()

# %%
import pandas as pd
import glob

path = r'C:/Users/vishal/Desktop/Candev/Social Media Data/CDNtour' # use your path
all_files = glob.glob(path + "/*.xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

CDNtour = pd.concat(li, axis=0, ignore_index=True)

# %%
CDNtour
# Out:
#                 Tweet id                                    Tweet permalink  \
# 0    1123248255830240000  https://twitter.com/cdntourism/status/11232482...
# 1    1122885831864320000  https://twitter.com/cdntourism/status/11228858...
# 2    1121905337207059968  https://twitter.com/cdntourism/status/11219053...
# 3    1121798719047789952  https://twitter.com/cdntourism/status/11217987...
# 4    1121767496179219968  https://twitter.com/cdntourism/status/11217674...
# 5    1121436313012640000  https://twitter.com/cdntourism/status/11214363...
# 6    1121135716900189952  https://twitter.com/cdntourism/status/11211357...
# 7    1121073909955209984  https://twitter.com/cdntourism/status/11210739...
# 8    1120711539009420032  https://twitter.com/cdntourism/status/11207115...
# 9    1119261978441200000  https://twitter.com/cdntourism/status/11192619...
# 10   1118899616945139968  https://twitter.com/cdntourism/status/11188996...
# ...

# %%
CDNtour= CDNtour.sort_values(by='time') 
CDNtour =  CDNtour.reset_index()

# %%
import pandas as pd
import glob

path = r'C:/Users/vishal/Desktop/Candev/Social Media Data/ISED tweet activity' # use your path
all_files = glob.glob(path + "/*.xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0)
    li.append(df)

ISED = pd.concat(li, axis=0, ignore_index=True)

# %%
ISED
# Out:
#                 Tweet id                                    Tweet permalink  \
# 0    1123250472159149952  https://twitter.com/ISED_CA/status/11232504721...
# 1    1121881803948679936  https://twitter.com/ISED_CA/status/11218818039...
# 2    1121869071996339968  https://twitter.com/ISED_CA/status/11218690719...
# 3    1121864118884089984  https://twitter.com/ISED_CA/status/11218641188...
# 4    1121854054362150016  https://twitter.com/ISED_CA/status/11218540543...
# 5    1121820214394520064  https://twitter.com/ISED_CA/status/11218202143...
# 6    1121761259026829952  https://twitter.com/ISED_CA/status/11217612590...
# 7    1121515793685020032  https://twitter.com/ISED_CA/status/11215157936...
# 8    1121515491443570048  https://twitter.com/ISED_CA/status/11215154914...
# 9    1121506308849629952  https://twitter.com/ISED_CA/status/11215063088...
# 10   1121446222877920000  https://twitter.com/ISED_CA/status/11214462228...
# ...

# %%
ISED = ISED.sort_values(by='time') 
ISED = ISED.reset_index()

# %%
ISED
# Out:
#      index             Tweet id  \
# 0      249  1101510002131549952
# 1      248  1101534265542610048
# 2      247  1101557890635250048
# 3      246  1102673176969069952
# 4      245  1102682659489280000
# 5      244  1102995582661149952
# 6      243  1102998724857479936
# 7      242  1103011066236320000
# 8      241  1103029944811219968
# 9      240  1103316072852320000
# 10     239  1103344116367320064
# 11     238  1103385012370589952
# 12     237  1103396100944349952
# 13     236  1103697785029900032
# 14     235  1103711760803069952
# 15     234  1103720741059640064
# 16     233  1103753466814610048
# 17     232  1104026711744739968
# 18     231  1104050423588099968
# 19     230  1104102028844899968
# 20     229  1104117124220480000
# 21     228  1105181925067709952
# 22     227  1105195724524909952
# 23     226  1105468713460029952
# 24     225  1105533577876429952
# 25     224  1105892571132419968
# 26     223  1106563791565789952
# 27     222  1107658148972839936
# ...

# %%
contactcentre
# Out:
#        index   SRT # SRT Status Date Closed  \
# 0       2165  495072     Closed  2019-01-02
# 1       3339  495171     Closed  2019-01-02
# 2       3338  495170     Closed  2019-01-02
# 3       3337  495052     Closed  2019-01-02
# 4       3336  495053     Closed  2019-01-02
# 5       3343  495179     Closed  2019-01-02
# 6       3353  495165     Closed  2019-01-02
# 7       3354  495158     Closed  2019-01-02
# 8       3355  495160     Closed  2019-01-02
# 9       3372  495191     Closed  2019-01-02
# 10      3371  495183     Closed  2019-01-02
# 11      3340  495166     Closed  2019-01-02
# 12      3370  495185     Closed  2019-01-02
# 13      3368  495187     Closed  2019-01-02
# 14      3367  495186     Closed  2019-01-02
# 15      3366  495200     Closed  2019-01-02
# 16      3365  495202     Closed  2019-01-02
# 17      3364  495199     Closed  2019-01-02
# 18      3363  495205     Closed  2019-01-02
# 19      3362  495203     Closed  2019-01-02
# ...

# %%
from datetime import datetime

now = datetime.now()

# %%
# Out:
# datetime.datetime(2020, 1, 18, 18, 17, 48, 708159)

# %%
print(now.strftime('%B'))
# Out:
# January

# %%
type(contactcentre)
# Out:
# pandas.core.frame.DataFrame

# %%
contactcentre.dtypes
# Out:
# index                          int64
# SRT #                          int64
# SRT Status                    object
# Date Closed           datetime64[ns]
# Client Group                  object
# Contact Method                object
# Postal/Zip Code               object
# City                          object
# Prov/State                    object
# Country                       object
# Language                      object
# Topic                         object
# Organization                  object
# Sector                        object
# Program                       object
# Prog. Area                    object
# Reason for Enquiry            object
# Resolution                    object
# dtype: object

# %%
import dateutil.parser
ISED['time'] = ISED['time'].apply(lambda x: dateutil.parser.parse(x).date())

# %%
contactcentre
# Out:
#        index   SRT # SRT Status Date Closed  \
# 0       2165  495072     Closed  2019-01-02
# 1       3339  495171     Closed  2019-01-02
# 2       3338  495170     Closed  2019-01-02
# 3       3337  495052     Closed  2019-01-02
# 4       3336  495053     Closed  2019-01-02
# 5       3343  495179     Closed  2019-01-02
# 6       3353  495165     Closed  2019-01-02
# 7       3354  495158     Closed  2019-01-02
# 8       3355  495160     Closed  2019-01-02
# 9       3372  495191     Closed  2019-01-02
# 10      3371  495183     Closed  2019-01-02
# 11      3340  495166     Closed  2019-01-02
# 12      3370  495185     Closed  2019-01-02
# 13      3368  495187     Closed  2019-01-02
# 14      3367  495186     Closed  2019-01-02
# 15      3366  495200     Closed  2019-01-02
# 16      3365  495202     Closed  2019-01-02
# 17      3364  495199     Closed  2019-01-02
# 18      3363  495205     Closed  2019-01-02
# 19      3362  495203     Closed  2019-01-02
# ...

# %%
contactcentre.to_excel(r'C:\Users\vishal\Desktop\contactcentre.xlsx')

# %%
ISED.to_excel(r'C:\Users\vishal\Desktop\ISED.xlsx')

# %%
ISED
# Out:
#      index             Tweet id  \
# 0      249  1101510002131549952
# 1      248  1101534265542610048
# 2      247  1101557890635250048
# 3      246  1102673176969069952
# 4      245  1102682659489280000
# 5      244  1102995582661149952
# 6      243  1102998724857479936
# 7      242  1103011066236320000
# 8      241  1103029944811219968
# 9      240  1103316072852320000
# 10     239  1103344116367320064
# 11     238  1103385012370589952
# 12     237  1103396100944349952
# 13     236  1103697785029900032
# 14     235  1103711760803069952
# 15     234  1103720741059640064
# 16     233  1103753466814610048
# 17     232  1104026711744739968
# 18     231  1104050423588099968
# 19     230  1104102028844899968
# 20     229  1104117124220480000
# 21     228  1105181925067709952
# 22     227  1105195724524909952
# 23     226  1105468713460029952
# 24     225  1105533577876429952
# 25     224  1105892571132419968
# 26     223  1106563791565789952
# 27     222  1107658148972839936
# ...

# %%
import dateutil.parser
CDNScience['time'] = CDNScience['time'].apply(lambda x: dateutil.parser.parse(x).date())

# %%
CDNScience.to_excel(r'C:\Users\vishal\Desktop\CDNScience.xlsx')

# %% [markdown]
# # All visualizations are done in Tableau and PowerBI
